# %% [markdown]
# 1.What is the difference between descriptive statistics and inferential
# statistics? Explain with examples.
# -->In Descriptive Statistics we Summarize the whole data by using Statistics methods , these are Measure of central tendency , Measure of Dispersion , Measure of Symetricity. In Inferential Statistics we take a sample from Population and we apply the statistical methods on the sample and we inference the result getting from sample to the whole population examples are CLT, PDF, PMF etc.
#
# 2.What is sampling in statistics? Explain the differences between random
# and stratified sampling.
# --> Sampling is mostly used for infrencial statistics , due to time and source constrain we take sample from whole population and apply statisical methods to get insights , this is sampling , there are various type of sampling techninque , in random sampling there is equal chance of all element in population to be in sample , but in stratified sampling we divide the population in some starta or layer then apply random sampling in each strata.
#
# 3.Define mean, median, and mode. Explain why these measures of central tendency are important.
# -->Mean , Median , Mode is the measure of central Tendency come under Descriptive Statistics , Mean and median is used for Numerical data and mode is used for categorical data ,  mean is the sum of all the element devide by number of element , median is the central element of the data set when it is in asscending or dessending order , mode is the element of maximum frequency , it is very useful for data summerization , comparision between datasets.
#
# 4.Explain skewness and kurtosis. What does a positive skew imply about the data?
# -->Skewness and kurtosis is the Measure of symmetricity comes under desciptive statistics , if the distribution of the data is symmetric then the its value is zero , positive skew means most of the data lies on right side , for positive skew mean>median>mode.

# %%
#5. Implement a Python program to compute the mean, median, and mode of a given list of numbers. numbers = [12, 15, 12, 18, 19, 12, 20, 22, 19, 19, 24, 24, 24, 26, 28]
import numpy as np
import statistics
numbers=[12, 15, 12, 18, 19, 12, 20, 22, 19, 19, 24, 24, 24, 26, 28]
mean=np.mean(numbers)
median=np.median(numbers)
mode=statistics.mode(numbers)
print(f"this mean is {mean}, median is {median}, mode is {mode}")
# Out:
# this mean is 19.6, median is 19.0, mode is 12

# %%
#6. Compute the covariance and correlation coefficient between the following two datasets provided as lists in Python list_x = [10, 20, 30, 40, 50],list_y = [15, 25, 35, 45, 60]
import numpy as np
import statistics
list_x = [10, 20, 30, 40, 50]
list_y = [15, 25, 35, 45, 60]
covariance=statistics.covariance(list_x,list_y)
correlation=statistics.correlation(list_x,list_y)
print(f"this covariance is {covariance}, correlation is {correlation}")
# Out:
# this covariance is 275.0, correlation is 0.9958932064677039

# %%
#7. Write a Python script to draw a boxplot for the following numeric list and identify its outliers. Explain the result: data = [12, 14, 14, 15, 18, 19, 19, 21, 22, 22, 23, 23, 24, 26, 29, 35]
import seaborn as sns
data = [12, 14, 14, 15, 18, 19, 19, 21, 22, 22, 23, 23, 24, 26, 29, 35]
sns.boxplot(data)
# Out:
# <Axes: >

# %%
#8  You are working as a data analyst in an e-commerce company. The marketing team wants to know if there is a relationship between advertising spend and
#daily sales. advertising_spend = [200, 250, 300, 400, 500] , daily_sales = [2200, 2450, 2750, 3200, 4000]
import statistics
advertising_spend = [200, 250, 300, 400, 500]
daily_sales = [2200, 2450, 2750, 3200, 4000]
covariance=statistics.covariance(advertising_spend,daily_sales)
correlation=statistics.correlation(advertising_spend,daily_sales)
print(f"this covariance is {covariance}, correlation is {correlation}")
# Out:
# this covariance is 84875.0, correlation is 0.9935824101653327

# %%
#9 Your team has collected customer satisfaction survey data on a scale of 1-10 and wants to understand its distribution before launching a new product survey_scores = [7, 8, 5, 9, 6, 7, 8, 9, 10, 4, 7, 6, 9, 8, 7].
import numpy as np
import seaborn as sns
from scipy.stats import skew
survey_scores = [7, 8, 5, 9, 6, 7, 8, 9, 10, 4, 7, 6, 9, 8, 7]
mean=np.mean(survey_scores)
standard_deviation=np.std(survey_scores)
skewness=skew(survey_scores)
print(f"this mean is {mean}, standard_deviation is {standard_deviation}, skewness is {skewness}")
sns.histplot(survey_scores,kde=True)
# Out:
# this mean is 7.333333333333333, standard_deviation is 1.577621275493231, skewness is -0.3546629461807162
# <Axes: ylabel='Count'>
