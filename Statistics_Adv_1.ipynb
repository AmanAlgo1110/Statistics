# %% [markdown]
# 1. What is a random variable in probability theory?
# -->the probaility we get from random experimenet is called random variable.
#
# 2.What are the types of random variables?
# -->There are two types of random variable one is discrete random variable and other is continuous random variable.
#
# 3. Explain the difference between discrete and continuous distributions?
# -->the outcome of discrete random variable is discrete and continous is contunous in nature , discrete random variable follows pmf and continous follows pdf.
#
# 4.What is a binomial distribution, and how is it used in probability?
# -->binomial distribution used for  discrete distibution comes under pmf , here out come is 1 or 0 or we can say sucess or faliure, out of n numer of events.
#
# 5.What is the standard normal distribution, and why is it important?
# --> standard normal distribution is often called as gaussian distribution or bell shaped distribution , is it important because most of the real world data follows this ditribution
#
# 6.What is the Central Limit Theorem (CLT), and why is it critical in statistics?
#
# --->CLT states that if we have a population of standard deviation σ and mean is μ and if we take a large number of sample from it with replacement ,the sample mean is in normally distributed , and the mean is  μ and standard deviation is σ/root_over(n).
#
# 7. What is the significance of confidence intervals in statistical analysis?
#  -->in infrential statistics we often calculate the statisitcal parameter in the sample and we inference it with population so rather then giving a single value we ofter says a interval values , such that in that range the value will lie.
#
# 8.What is the concept of expected value in a probability distribution?
# -->The expected value of a probability distribution is the long-run average outcome you would expect if you repeated an experiment many times. It is calculated by multiplying each possible value of a random variable by its probability and then summing up these products.

# %%
9. # Write a Python program to generate 1000 random numbers from a normal
# distribution with mean = 50 and standard deviation = 5. Compute its mean and standard
# deviation using NumPy, and draw a histogram to visualize the distribution.
import numpy as np
import seaborn as sns
data=np.random.normal(50,5,100)
sns.histplot(data,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
#10. You are working as a data analyst for a retail company. The company has
# collected daily sales data for 2 years and wants you to identify the overall sales trend.
# daily_sales = [220, 245, 210, 265, 230, 250, 260, 275, 240, 255,
#  235, 260, 245, 250, 225, 270, 265, 255, 250, 260]
# ● Explain how you would apply the Central Limit Theorem to estimate the average sales
# with a 95% confidence interval.
# ● Write the Python code to compute the mean sales and its confidence interval.
import numpy as np
import math
import matplotlib.pyplot as plt
import scipy.stats as stats
daily_sales = [220, 245, 210, 265, 230, 250, 260, 275, 240, 255,
               235, 260, 245, 250, 225, 270, 265, 255, 250, 260]
daily_sales=np.array(daily_sales)
mean=np.mean(daily_sales)
std_dev=np.std(daily_sales,ddof=1)
n=len(daily_sales)
std_error=std_dev/math.sqrt(n)
z=stats.norm.ppf(1-((1-.95)/2))
ci_lower=mean-(z*std_error)
ci_higher=mean+(z*std_error)
print(f"the mean sale if {mean}")
print(f"the ci_lower is: {ci_lower}")
print(f"the ci_higher is: {ci_higher}")
# Out:
# the mean sale if 248.25
# the ci_lower is: 240.68326838343515
# the ci_higher is: 255.81673161656485
